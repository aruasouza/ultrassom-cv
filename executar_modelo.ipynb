# %%
import os
import random
from modelo import load,Model
from plot import plot_pred

# %%
folder = 'ARRAY_FORMAT'
data_files = [os.path.join(folder,name) for name in os.listdir(folder)]

# %%
model = Model('MODEL')

# %%
n = random.randint(0,1500)

img,struc = load(data_files[n])
prediction = model.predict(img)

plot_pred(img,struc,prediction)
